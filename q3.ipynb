# %%
from models import BaselineClassifier
from data import load_imdb, load_imdb_synth, load_xor
import torch
import torch.nn as nn
from torch import device
from q1 import pad_batch
import random
import torch.nn.functional as F
import itertools

# %%
(x_train_1, y_train_1), (x_val_1, y_val_1), (i2w_1, w2i_1), numcls_1 = load_imdb(final=False)
train_data1 = (x_train_1, y_train_1)
val_data1   = (x_val_1, y_val_1)

# %%
(x_train_2, y_train_2), (x_val_2, y_val_2), (i2w_2, w2i_2), numcls_2 = load_imdb_synth()
train_data2 = (x_train_2, y_train_2)
val_data2   = (x_val_2, y_val_2)

# %%
(x_train_3, y_train_3), (x_val_3, y_val_3), (i2w_3, w2i_3), numcls_3 = load_xor()
train_data3 = (x_train_3, y_train_3)
val_data3   = (x_val_3, y_val_3)

# %%
def iterate_batches(dataset, batch_size, pad_idx, shuffle=True):
    """
    dataset: (x_list, y_list)
    returns a list of (x_batch, y_batch) tuples
    """
    x_data, y_data = dataset
    indices = list(range(len(x_data)))

    batches = []
    for start in range(0, len(indices), batch_size):
        batch_idx = indices[start:start + batch_size]
        x_seqs = [x_data[j] for j in batch_idx]
        y_labels = [y_data[j] for j in batch_idx]

        x = pad_batch(x_seqs, pad_idx)              # (B, T)
        y = torch.tensor(y_labels, dtype=torch.long)  # (B,)
        batches.append((x, y))
    return batches

# %%
def train_epochs(model, train_data, batch_size, pad_idx, optimizer, num_epochs=5):

    for epoch in range(1, num_epochs + 1):
        total_loss = 0.0       
        total_correct = 0
        total_examples = 0

        print(f"\nEpoch {epoch}/{num_epochs}")

        for x, y in iterate_batches(train_data, batch_size, pad_idx, shuffle=True):

            optimizer.zero_grad()
            output = model(x)
            loss = F.cross_entropy(output, y)

            loss.backward()
            optimizer.step()

            # stats for this batch
            batch_size_actual = x.size(0)
            total_loss += loss.item() * batch_size_actual
            preds = output.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_examples += batch_size_actual

        # epoch metrics
        avg_loss = total_loss / total_examples
        acc = total_correct / total_examples
        
        print(f"Training loss: {avg_loss:.4f}  |  accuracy: {acc:.4f}")

    return avg_loss, acc

# %%
def evaluate(model, val_data, batch_size, pad_idx):
    total_loss = 0.0
    total_correct = 0
    total_examples = 0

    with torch.no_grad():
        for x, y in iterate_batches(val_data, batch_size, pad_idx, shuffle=False):
            output = model(x)
            loss = F.cross_entropy(output, y)

            batch_size_actual = x.size(0)
            total_loss += loss.item() * batch_size_actual

            preds = output.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_examples += batch_size_actual

    avg_loss = total_loss / total_examples
    acc = total_correct / total_examples
    return avg_loss, acc

# %%
baseline = BaselineClassifier(vocab_size=len(i2w_1))
optimizer = torch.optim.Adam(baseline.parameters(), lr=0.001)
batch_size = 64
pad_idx1 = w2i_1['.pad']

# %%
def grid_search(train_data, val_data, vocab_size, num_classes, pad_idx):
    pools = ['mean', 'max', 'first']
    lrs = [1e-3, 3e-4]
    batch_sizes = [64, 128]

    results = []

    for batch_size in batch_sizes:
        for lr, pool in itertools.product(lrs, pools):
            # fresh model + optimizer for each run
            model = BaselineClassifier(vocab_size=vocab_size, emb_dim=300, num_classes=num_classes, pool=pool)
            optimizer = torch.optim.Adam(model.parameters(), lr=lr)

            train_loss, train_acc = train_epochs(model, train_data, batch_size, pad_idx, optimizer)
            val_loss, val_acc = evaluate(model, val_data, batch_size, pad_idx)

            print(f'pool={pool}, lr={lr}, batch={batch_size} | train_acc={train_acc:.3f}, val_acc={val_acc:.3f}')
            results.append((pool, lr, batch_size, train_acc, val_acc))

    return results

# %%
results1 = grid_search(train_data1, val_data1, vocab_size=len(i2w_1), num_classes=numcls_1, pad_idx=pad_idx1)
# Out:
# Epoch 1/5
# Training loss: 0.6114  |  accuracy: 0.7201
#
# Epoch 2/5
# Training loss: 0.4179  |  accuracy: 0.8486
#
# Epoch 3/5
# Training loss: 0.3012  |  accuracy: 0.8946
#
# Epoch 4/5
# Training loss: 0.2366  |  accuracy: 0.9212
#
# Epoch 5/5
# Training loss: 0.1922  |  accuracy: 0.9390
# pool=mean, lr=0.001, batch=64 | train_acc=0.939, val_acc=0.885
#
# Epoch 1/5
# Training loss: 0.6754  |  accuracy: 0.5863
#
# Epoch 2/5
# Training loss: 0.5780  |  accuracy: 0.7216
#
# Epoch 3/5
# Training loss: 0.4780  |  accuracy: 0.8062
#
# Epoch 4/5
# Training loss: 0.3926  |  accuracy: 0.8539
#
# Epoch 5/5
# Training loss: 0.3298  |  accuracy: 0.8795
# pool=max, lr=0.001, batch=64 | train_acc=0.879, val_acc=0.827
#
# Epoch 1/5
# Training loss: 0.7072  |  accuracy: 0.5228
#
# Epoch 2/5
# Training loss: 0.6827  |  accuracy: 0.5545
#
# Epoch 3/5
# Training loss: 0.6682  |  accuracy: 0.5706
#
# Epoch 4/5
# Training loss: 0.6538  |  accuracy: 0.5842
#
# Epoch 5/5
# Training loss: 0.6406  |  accuracy: 0.5917
# pool=first, lr=0.001, batch=64 | train_acc=0.592, val_acc=0.548
#
# Epoch 1/5
# Training loss: 0.6718  |  accuracy: 0.6459
#
# Epoch 2/5
# Training loss: 0.6145  |  accuracy: 0.7399
#
# Epoch 3/5
# Training loss: 0.5436  |  accuracy: 0.7887
#
# Epoch 4/5
# Training loss: 0.4712  |  accuracy: 0.8294
#
# Epoch 5/5
# Training loss: 0.4088  |  accuracy: 0.8570
# pool=mean, lr=0.0003, batch=64 | train_acc=0.857, val_acc=0.834
#
# Epoch 1/5
# Training loss: 0.7040  |  accuracy: 0.5353
#
# Epoch 2/5
# Training loss: 0.6712  |  accuracy: 0.5894
#
# Epoch 3/5
# Training loss: 0.6476  |  accuracy: 0.6398
#
# Epoch 4/5
# Training loss: 0.6230  |  accuracy: 0.6830
#
# Epoch 5/5
# Training loss: 0.5971  |  accuracy: 0.7205
# pool=max, lr=0.0003, batch=64 | train_acc=0.720, val_acc=0.693
#
# Epoch 1/5
# Training loss: 0.7173  |  accuracy: 0.5192
#
# Epoch 2/5
# Training loss: 0.6957  |  accuracy: 0.5392
#
# Epoch 3/5
# Training loss: 0.6862  |  accuracy: 0.5504
#
# Epoch 4/5
# Training loss: 0.6795  |  accuracy: 0.5602
#
# Epoch 5/5
# Training loss: 0.6736  |  accuracy: 0.5684
# pool=first, lr=0.0003, batch=64 | train_acc=0.568, val_acc=0.541
#
# Epoch 1/5
# Training loss: 0.6417  |  accuracy: 0.6815
#
# Epoch 2/5
# Training loss: 0.5129  |  accuracy: 0.7891
#
# Epoch 3/5
# Training loss: 0.3985  |  accuracy: 0.8556
#
# Epoch 4/5
# Training loss: 0.3172  |  accuracy: 0.8891
#
# Epoch 5/5
# Training loss: 0.2623  |  accuracy: 0.9120
# pool=mean, lr=0.001, batch=128 | train_acc=0.912, val_acc=0.877
#
# Epoch 1/5
# Training loss: 0.7031  |  accuracy: 0.5383
#
# Epoch 2/5
# Training loss: 0.6423  |  accuracy: 0.6359
#
# Epoch 3/5
# Training loss: 0.5817  |  accuracy: 0.7250
#
# Epoch 4/5
# Training loss: 0.5162  |  accuracy: 0.7881
#
# Epoch 5/5
# Training loss: 0.4525  |  accuracy: 0.8300
# pool=max, lr=0.001, batch=128 | train_acc=0.830, val_acc=0.790
#
# Epoch 1/5
# Training loss: 0.7078  |  accuracy: 0.5198
#
# Epoch 2/5
# Training loss: 0.6848  |  accuracy: 0.5499
#
# Epoch 3/5
# Training loss: 0.6732  |  accuracy: 0.5669
#
# Epoch 4/5
# Training loss: 0.6617  |  accuracy: 0.5803
#
# Epoch 5/5
# Training loss: 0.6501  |  accuracy: 0.5870
# pool=first, lr=0.001, batch=128 | train_acc=0.587, val_acc=0.542
#
# Epoch 1/5
# Training loss: 0.6803  |  accuracy: 0.6161
#
# Epoch 2/5
# Training loss: 0.6433  |  accuracy: 0.7080
#
# Epoch 3/5
# Training loss: 0.5967  |  accuracy: 0.7552
#
# Epoch 4/5
# Training loss: 0.5429  |  accuracy: 0.7902
#
# Epoch 5/5
# Training loss: 0.4888  |  accuracy: 0.8201
# pool=mean, lr=0.0003, batch=128 | train_acc=0.820, val_acc=0.805
#
# Epoch 1/5
# Training loss: 0.6894  |  accuracy: 0.5436
#
# Epoch 2/5
# Training loss: 0.6673  |  accuracy: 0.5923
#
# Epoch 3/5
# Training loss: 0.6464  |  accuracy: 0.6358
#
# Epoch 4/5
# Training loss: 0.6256  |  accuracy: 0.6696
#
# Epoch 5/5
# Training loss: 0.6047  |  accuracy: 0.7022
# pool=max, lr=0.0003, batch=128 | train_acc=0.702, val_acc=0.685
#
# Epoch 1/5
# Training loss: 0.7206  |  accuracy: 0.5148
#
# Epoch 2/5
# Training loss: 0.6966  |  accuracy: 0.5348
#
# Epoch 3/5
# Training loss: 0.6881  |  accuracy: 0.5462
#
# Epoch 4/5
# Training loss: 0.6823  |  accuracy: 0.5548
#
# Epoch 5/5
# Training loss: 0.6776  |  accuracy: 0.5606
# pool=first, lr=0.0003, batch=128 | train_acc=0.561, val_acc=0.539

# %%
results2 = grid_search(train_data2, val_data2, vocab_size=len(i2w_2), num_classes=numcls_2, pad_idx=w2i_2['.pad'])
# Out:
# Epoch 1/5
# Training loss: 0.6975  |  accuracy: 0.4986
#
# Epoch 2/5
# Training loss: 0.6965  |  accuracy: 0.4989
#
# Epoch 3/5
# Training loss: 0.6964  |  accuracy: 0.4991
#
# Epoch 4/5
# Training loss: 0.6964  |  accuracy: 0.4994
#
# Epoch 5/5
# Training loss: 0.6963  |  accuracy: 0.4986
# pool=mean, lr=0.001, batch=64 | train_acc=0.499, val_acc=0.493
#
# Epoch 1/5
# Training loss: 0.4076  |  accuracy: 0.8890
#
# Epoch 2/5
# Training loss: 0.0594  |  accuracy: 1.0000
#
# Epoch 3/5
# Training loss: 0.0140  |  accuracy: 1.0000
#
# Epoch 4/5
# Training loss: 0.0058  |  accuracy: 1.0000
#
# Epoch 5/5
# Training loss: 0.0030  |  accuracy: 1.0000
# pool=max, lr=0.001, batch=64 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6992  |  accuracy: 0.4962
#
# Epoch 2/5
# Training loss: 0.6988  |  accuracy: 0.4965
#
# Epoch 3/5
# Training loss: 0.6987  |  accuracy: 0.4951
#
# Epoch 4/5
# Training loss: 0.6986  |  accuracy: 0.4947
#
# Epoch 5/5
# Training loss: 0.6985  |  accuracy: 0.4947
# pool=first, lr=0.001, batch=64 | train_acc=0.495, val_acc=0.499
#
# Epoch 1/5
# Training loss: 0.6964  |  accuracy: 0.5033
#
# Epoch 2/5
# Training loss: 0.6940  |  accuracy: 0.5063
#
# Epoch 3/5
# Training loss: 0.6937  |  accuracy: 0.5051
#
# Epoch 4/5
# Training loss: 0.6936  |  accuracy: 0.5066
#
# Epoch 5/5
# Training loss: 0.6935  |  accuracy: 0.5066
# pool=mean, lr=0.0003, batch=64 | train_acc=0.507, val_acc=0.501
#
# Epoch 1/5
# Training loss: 0.6114  |  accuracy: 0.7235
#
# Epoch 2/5
# Training loss: 0.3463  |  accuracy: 0.9932
#
# Epoch 3/5
# Training loss: 0.1596  |  accuracy: 1.0000
#
# Epoch 4/5
# Training loss: 0.0734  |  accuracy: 1.0000
#
# Epoch 5/5
# Training loss: 0.0380  |  accuracy: 1.0000
# pool=max, lr=0.0003, batch=64 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6960  |  accuracy: 0.4984
#
# Epoch 2/5
# Training loss: 0.6951  |  accuracy: 0.4983
#
# Epoch 3/5
# Training loss: 0.6951  |  accuracy: 0.4981
#
# Epoch 4/5
# Training loss: 0.6951  |  accuracy: 0.4983
#
# Epoch 5/5
# Training loss: 0.6951  |  accuracy: 0.4983
# pool=first, lr=0.0003, batch=64 | train_acc=0.498, val_acc=0.501
#
# Epoch 1/5
# Training loss: 0.6968  |  accuracy: 0.4967
#
# Epoch 2/5
# Training loss: 0.6954  |  accuracy: 0.4972
#
# Epoch 3/5
# Training loss: 0.6954  |  accuracy: 0.4980
#
# Epoch 4/5
# Training loss: 0.6953  |  accuracy: 0.4981
#
# Epoch 5/5
# Training loss: 0.6953  |  accuracy: 0.4986
# pool=mean, lr=0.001, batch=128 | train_acc=0.499, val_acc=0.499
#
# Epoch 1/5
# Training loss: 0.5425  |  accuracy: 0.8170
#
# Epoch 2/5
# Training loss: 0.1921  |  accuracy: 0.9993
#
# Epoch 3/5
# Training loss: 0.0540  |  accuracy: 1.0000
#
# Epoch 4/5
# Training loss: 0.0217  |  accuracy: 1.0000
#
# Epoch 5/5
# Training loss: 0.0113  |  accuracy: 1.0000
# pool=max, lr=0.001, batch=128 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6972  |  accuracy: 0.4964
#
# Epoch 2/5
# Training loss: 0.6964  |  accuracy: 0.4980
#
# Epoch 3/5
# Training loss: 0.6964  |  accuracy: 0.4974
#
# Epoch 4/5
# Training loss: 0.6964  |  accuracy: 0.4974
#
# Epoch 5/5
# Training loss: 0.6963  |  accuracy: 0.4978
# pool=first, lr=0.001, batch=128 | train_acc=0.498, val_acc=0.499
#
# Epoch 1/5
# Training loss: 0.6984  |  accuracy: 0.4938
#
# Epoch 2/5
# Training loss: 0.6940  |  accuracy: 0.5022
#
# Epoch 3/5
# Training loss: 0.6934  |  accuracy: 0.5081
#
# Epoch 4/5
# Training loss: 0.6932  |  accuracy: 0.5098
#
# Epoch 5/5
# Training loss: 0.6931  |  accuracy: 0.5097
# pool=mean, lr=0.0003, batch=128 | train_acc=0.510, val_acc=0.494
#
# Epoch 1/5
# Training loss: 0.6453  |  accuracy: 0.6567
#
# Epoch 2/5
# Training loss: 0.5066  |  accuracy: 0.9209
#
# Epoch 3/5
# Training loss: 0.3663  |  accuracy: 0.9914
#
# Epoch 4/5
# Training loss: 0.2443  |  accuracy: 0.9994
#
# Epoch 5/5
# Training loss: 0.1567  |  accuracy: 1.0000
# pool=max, lr=0.0003, batch=128 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6943  |  accuracy: 0.5013
#
# Epoch 2/5
# Training loss: 0.6941  |  accuracy: 0.4999
#
# Epoch 3/5
# Training loss: 0.6941  |  accuracy: 0.4999
#
# Epoch 4/5
# Training loss: 0.6941  |  accuracy: 0.4999
#
# Epoch 5/5
# Training loss: 0.6941  |  accuracy: 0.4999
# pool=first, lr=0.0003, batch=128 | train_acc=0.500, val_acc=0.501

# %%
results3 = grid_search(train_data3, val_data3, vocab_size=len(i2w_3), num_classes=numcls_3, pad_idx=w2i_3['.pad'])
# Out:
# Epoch 1/5
# Training loss: 0.7002  |  accuracy: 0.4824
#
# Epoch 2/5
# Training loss: 0.6993  |  accuracy: 0.4898
#
# Epoch 3/5
# Training loss: 0.6992  |  accuracy: 0.4947
#
# Epoch 4/5
# Training loss: 0.6991  |  accuracy: 0.4926
#
# Epoch 5/5
# Training loss: 0.6990  |  accuracy: 0.4943
# pool=mean, lr=0.001, batch=64 | train_acc=0.494, val_acc=0.500
#
# Epoch 1/5
# Training loss: 0.0239  |  accuracy: 0.9957
#
# Epoch 2/5
# Training loss: 0.0007  |  accuracy: 1.0000
#
# Epoch 3/5
# Training loss: 0.0003  |  accuracy: 1.0000
#
# Epoch 4/5
# Training loss: 0.0002  |  accuracy: 1.0000
#
# Epoch 5/5
# Training loss: 0.0001  |  accuracy: 1.0000
# pool=max, lr=0.001, batch=64 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6998  |  accuracy: 0.5000
#
# Epoch 2/5
# Training loss: 0.6994  |  accuracy: 0.5013
#
# Epoch 3/5
# Training loss: 0.6992  |  accuracy: 0.4999
#
# Epoch 4/5
# Training loss: 0.6991  |  accuracy: 0.4994
#
# Epoch 5/5
# Training loss: 0.6990  |  accuracy: 0.4992
# pool=first, lr=0.001, batch=64 | train_acc=0.499, val_acc=0.499
#
# Epoch 1/5
# Training loss: 0.6972  |  accuracy: 0.5110
#
# Epoch 2/5
# Training loss: 0.6949  |  accuracy: 0.5139
#
# Epoch 3/5
# Training loss: 0.6950  |  accuracy: 0.5139
#
# Epoch 4/5
# Training loss: 0.6950  |  accuracy: 0.5126
#
# Epoch 5/5
# Training loss: 0.6950  |  accuracy: 0.5139
# pool=mean, lr=0.0003, batch=64 | train_acc=0.514, val_acc=0.750
#
# Epoch 1/5
# Training loss: 0.0961  |  accuracy: 0.9817
#
# Epoch 2/5
# Training loss: 0.0063  |  accuracy: 1.0000
#
# Epoch 3/5
# Training loss: 0.0025  |  accuracy: 1.0000
#
# Epoch 4/5
# Training loss: 0.0013  |  accuracy: 1.0000
#
# Epoch 5/5
# Training loss: 0.0008  |  accuracy: 1.0000
# pool=max, lr=0.0003, batch=64 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6994  |  accuracy: 0.4991
#
# Epoch 2/5
# Training loss: 0.6956  |  accuracy: 0.5004
#
# Epoch 3/5
# Training loss: 0.6956  |  accuracy: 0.5005
#
# Epoch 4/5
# Training loss: 0.6956  |  accuracy: 0.5012
#
# Epoch 5/5
# Training loss: 0.6957  |  accuracy: 0.5022
# pool=first, lr=0.0003, batch=64 | train_acc=0.502, val_acc=0.501
#
# Epoch 1/5
# Training loss: 0.6966  |  accuracy: 0.5128
#
# Epoch 2/5
# Training loss: 0.6964  |  accuracy: 0.5077
#
# Epoch 3/5
# Training loss: 0.6964  |  accuracy: 0.5049
#
# Epoch 4/5
# Training loss: 0.6964  |  accuracy: 0.5019
#
# Epoch 5/5
# Training loss: 0.6963  |  accuracy: 0.5021
# pool=mean, lr=0.001, batch=128 | train_acc=0.502, val_acc=0.500
#
# Epoch 1/5
# Training loss: 0.0349  |  accuracy: 0.9951
#
# Epoch 2/5
# Training loss: 0.0016  |  accuracy: 1.0000
#
# Epoch 3/5
# Training loss: 0.0007  |  accuracy: 1.0000
#
# Epoch 4/5
# Training loss: 0.0004  |  accuracy: 1.0000
#
# Epoch 5/5
# Training loss: 0.0003  |  accuracy: 1.0000
# pool=max, lr=0.001, batch=128 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6982  |  accuracy: 0.5017
#
# Epoch 2/5
# Training loss: 0.6980  |  accuracy: 0.4991
#
# Epoch 3/5
# Training loss: 0.6979  |  accuracy: 0.4993
#
# Epoch 4/5
# Training loss: 0.6979  |  accuracy: 0.4982
#
# Epoch 5/5
# Training loss: 0.6978  |  accuracy: 0.4979
# pool=first, lr=0.001, batch=128 | train_acc=0.498, val_acc=0.501
#
# Epoch 1/5
# Training loss: 0.6959  |  accuracy: 0.4806
#
# Epoch 2/5
# Training loss: 0.6943  |  accuracy: 0.4976
#
# Epoch 3/5
# Training loss: 0.6943  |  accuracy: 0.4923
#
# Epoch 4/5
# Training loss: 0.6943  |  accuracy: 0.4921
#
# Epoch 5/5
# Training loss: 0.6943  |  accuracy: 0.4943
# pool=mean, lr=0.0003, batch=128 | train_acc=0.494, val_acc=0.250
#
# Epoch 1/5
# Training loss: 0.1143  |  accuracy: 0.9866
#
# Epoch 2/5
# Training loss: 0.0120  |  accuracy: 1.0000
#
# Epoch 3/5
# Training loss: 0.0052  |  accuracy: 1.0000
#
# Epoch 4/5
# Training loss: 0.0029  |  accuracy: 1.0000
#
# Epoch 5/5
# Training loss: 0.0019  |  accuracy: 1.0000
# pool=max, lr=0.0003, batch=128 | train_acc=1.000, val_acc=1.000
#
# Epoch 1/5
# Training loss: 0.6956  |  accuracy: 0.4992
#
# Epoch 2/5
# Training loss: 0.6950  |  accuracy: 0.4969
#
# Epoch 3/5
# Training loss: 0.6950  |  accuracy: 0.4974
#
# Epoch 4/5
# Training loss: 0.6950  |  accuracy: 0.4974
#
# Epoch 5/5
# Training loss: 0.6950  |  accuracy: 0.4974
# pool=first, lr=0.0003, batch=128 | train_acc=0.497, val_acc=0.500
